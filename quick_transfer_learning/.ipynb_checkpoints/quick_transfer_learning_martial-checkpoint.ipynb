# %% [markdown]
# # Quick Transfer Learning with fastai
#
# ## Classify Taekwondo vs Judo Matches

# %%
from fastai import *
from fastai.vision import *

import matplotlib.pyplot as plt
import numpy as np
from os import listdir
from os.path import isfile, join
from PIL import Image
# %matplotlib inline

# %% [markdown]
# ### Path to images

# %%
path = Path('/home/jupyter/myDir/fastai/martial/') # contains subdirectories: "happy" and "angry", with their corresponding images.

# %% [markdown]
# ### Show some examples

# %%
def showExamples(ids):
    fig=plt.figure(figsize=(15, 15))
    for i,j in enumerate(ids):
        image = Image.open(pathToClass/(images[j]))
        fig.add_subplot(1,len(ids),i+1)
        plt.imshow(np.asarray(image))
        plt.axis("off")
    plt.show()

# %% [markdown]
# #### Taekwondo matches

# %%
pathToClass = path/'tkd'
images = [f for f in listdir(pathToClass) if isfile(join(pathToClass, f))]
print("A total of", len(images), "images with taekwondo matches.")
showExamples([55,105,150,170])
# Out:
# A total of 377 images with taekwondo matches.

# %% [markdown]
# #### Judo matches

# %%
pathToClass = path/'judo'
images = [f for f in listdir(pathToClass) if isfile(join(pathToClass, f))]
print("A total of", len(images), "images with judo matches.")
showExamples([30,120,135,230])
# Out:
# A total of 327 images with judo matches.

# %% [markdown]
# ## Read data
#
# - Leave 30% for validation.
#
# - Apply default data augmentation transformations.

# %%
data = ImageDataBunch.from_folder(path, train=".", valid_pct=0.3,
        ds_tfms=get_transforms(), size=224, num_workers=4).normalize(imagenet_stats)

# %%
data.classes
# Out:
# ['tkd', 'judo']

# %% [markdown]
# #### Show some images used for training

# %%
data.show_batch(rows=4, figsize=(14,16))

# %%
print("Number of examples in training:", len(data.train_ds))
print("Number of examples in validation:", len(data.valid_ds))
# Out:
# Number of examples in training: 493
# Number of examples in validation: 211

# %% [markdown]
# ## Train model
#
# #### Apply transfer learning using resnet34, tuning the parameters of the last layer.

# %%
learn = create_cnn(data, models.resnet34, metrics=error_rate)

# %% [markdown]
# #### Learn through 10 epochs; error rate is on validation set

# %%
learn.fit_one_cycle(10)
# Out:
# Total time: 01:42
# epoch  train_loss  valid_loss  error_rate
# 1      0.565951    0.287632    0.113744    (00:09)
# 2      0.355775    0.126477    0.052133    (00:10)
# 3      0.242132    0.097797    0.037915    (00:10)
# 4      0.184831    0.098216    0.037915    (00:09)
# 5      0.146332    0.101453    0.028436    (00:10)
# 6      0.118280    0.091745    0.028436    (00:10)
# 7      0.096682    0.088624    0.018957    (00:10)
# 8      0.081367    0.090070    0.023697    (00:09)
# 9      0.071559    0.090443    0.023697    (00:10)
# 10     0.067890    0.090632    0.023697    (00:11)

# %% [markdown]
# ### Error rate on validation: 2.4% (accuracy 97.6%)

# %%
learn.save('martial-1')

# %%
#learn.load('martial-1')

# %% [markdown]
# ## Confusion matrix on the validation set

# %%
interp = ClassificationInterpretation.from_learner(learn)

# %%
interp.plot_confusion_matrix()

# %% [markdown]
# ## Cases with highest loss
#
# As shown in the confusion matrix, there are 5 misclassifications. These 5 cases are shown next, along with the prediction made, the actual class, the loss value, and the probability estimated for the correct class.
#
# Then, 4 more cases with high loss are shown, although they are correctly classified.

# %%
interp.plot_top_losses(9)
